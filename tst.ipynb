# %%
data = [{'time': '2025-11-02T12:00:00Z', 'price': '98.68'},
        {'time': '2025-11-02T12:00:00Z', 'price': '99.19'}]

# %%
# from dateutil import parser
import dateutil.parser
import datetime
from datetime import timedelta, date, datetime

# %%
time_datetime = dateutil.parser.parse(data[0]['time'])
time_datetime
# Out:
# datetime.datetime(2025, 11, 2, 12, 0, tzinfo=tzutc())

# %%
timenow = time_datetime  + timedelta()
# timenow = time_datetime  + timedelta(hours=5, minutes=30)

timenow
# Out:
# datetime.datetime(2025, 11, 2, 12, 0, tzinfo=tzutc())

# %%
timenow_dt = timenow.strftime("%m/%d/%Y %H:%M:%S")
timenow_dt
# Out:
# '11/02/2025 12:00:00'
